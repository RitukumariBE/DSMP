# %% [markdown]
# # Python Basics

# %% [markdown]
# ### Why Python ?
# -Design Philosphy<br>
# -Batteries Included<br>
# -General Purpose<br>
# -Libraries/Community<br>

# %% [markdown]
# ## Python Output

# %%
# Python is a case sensitive language
print('Salman Khan')
print(7)
print(7.7)
print(True)
print('Hello',1,4.5,True)
# Out:
# Salman Khan
# 7
# 7.7
# True
# Hello 1 4.5 True

# %%
# sep
print('Hello',1,4.5,True,sep = '/')
# Out:
# Hello/1/4.5/True

# %%
# end
print('hello',end = '-')
print('world')
# Out:
# hello-world

# %% [markdown]
# ## Data Type

# %%
#Integer
print(8)
#max = 1*10^308
# Out:
# 8

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5 + 6j)
# Out:
# (5+6j)

# %%
# List
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#Dictionary
print({'name':'NItish','Gender':'Male','Weight':70})
# Out:
# {'name': 'NItish', 'Gender': 'Male', 'Weight': 70}

# %%
#type
print(type(4))
# Out:
# <class 'int'>

# %% [markdown]
# ## Variables- Used to represent any value
# - static v/s Dynamic Binding
# - Static v/s Dynamic Typing
# - Stylish Declaration

# %%
# stylish declaration
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a = b = c =3
print(a,b,c)
# Out:
# 3 3 3

# %% [markdown]
# ## Comments
# - used to write line which system can't see

# %%
# this is comment
a = 4
b = 6 # like this
# second comment
print (a + b)

# Multiline comment are not supported in Python
# Out:
# 10

# %% [markdown]
# ## Keywords & Identifiers
# - keywords - the special words which are reserved for the python which can't be used normally
# - Identifiers -<br>
# 1. You can't start with a digit<br>
# 2. You can't use special chars(_)
# 3. Identifiers can't be keywords.

# %% [markdown]
# ## User Input

# %%
# static v/s Dynamic
input()
# Out:
# 5
# '5'

# %% [markdown]
# ## Type Conversion

# %%
# Implicit v/s Explicit
#Implicit
print(5 + 5.6)
# Out:
# 10.6

# %%
#Explicit
# str -> int
int (4.5)
# Out:
# 4

# %%
# sum of two numbers
fnum = input('Enter first number')
snum = input('Enter second number')
result = int(fnum)+ int(snum)
print(result);
print(type(fnum))
# Out:
# Enter first number12
# Enter second number12
# 24
# <class 'str'>

# %% [markdown]
# ## Literals

# %%
a = 0b1010 # binary literals
b = 100 # decimal Literal
c = 00310 # octal literal
d = 0x12c # hexadecimal Literal

# Float Literal
float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5e-3

# Complex Literal
x = 3.14j
print(a,b,c,d)
print(float_1,float_2,float_3);
print(x,x.imag,x.real)

string = 'This is Pyhton'
strings = "This is Python"
char = "c"
multiline_str = """This is multiline string"""
unicode = u"\U0001f600\U0001f606\U0001f923"
raw_str = r"raw\n String"
# Out:
#   File "/tmp/ipykernel_1976/2228690639.py", line 3
#     c = 00310 # octal literal
#         ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
a = True + 4
b = False + 10
print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %%
a = None
print(a)
# Out:
# None
